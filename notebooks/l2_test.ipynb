# %%
import numpy as np
from scipy.stats import zscore

# %%
X = random_array = np.random.rand(10)
Y = random_array = np.random.rand(10)


X = zscore(X)
Y = zscore(Y)

print(np.mean(X), np.std(X))
print(np.mean(Y), np.std(Y))
# Out:
# 0.0 1.0
# 1.3322676295501878e-16 0.9999999999999999

# %%
dist = np.linalg.norm(X-Y)
dist
# Out:
# 2.751034824493062

# %%
buf = ((X-Y))
buf = buf@buf
np.sqrt(buf)
# Out:
# 2.751034824493062

# %%
res = 0
for a,b in zip(X, Y):
    res += (a-b)**2
np.sqrt(res)
# Out:
# 2.7510348244930616

# %%
m = len(X)
np.sqrt(2*m*(1-(X@Y/m)))
# Out:
# 2.751034824493062
